# %%
# Extract Balance Sheet Data from
import pandas as pd
import json
from mistral_connect import mistral_con
from postgres_connect import pg_conn


json_data = [
    {
        "updated_at": "2025-02-04",
        "id_financial_report": "PYPL_2024Q4",   
        "fiscal_year": 2024,
        "period": "Q4",
        "id_balance_sheet": "PYPL_BS_2024Q4",   
        "cash_and_cashequivalents": 6561,       
        "short_term_investments": 4262,
        "cash_and_shortterm_investments": 10823,
        "net_receivables": 984,
        "accounts_receivables": 984,
        "other_receivables": 0,
        "inventory": 0,
        "prepaids": 4651,
        "other_current_assets": 0,
        "total_current_assets": 61092,
        "property_plant_equipment_net": 1508,   
        "goodwill": 10837,
        "intangible_assets": 326,
        "goodwill_and_intangible_assets": 11163,
        "long_term_investments": 4583,
        "tax_assets": 0,
        "other_noncurrent_assets": 3265,
        "total_noncurrent_assets": 19011,
        "other_assets": 3265,
        "total_assets": 81611,
        "total_payables": 8478,
        "account_payables": 227,
        "other_payables": 0,
        "accrued_expenses": 8478,
        "shortterm_debt": 0,
        "capitallease_obligations_current": 0,
        "tax_payables": 0,
        "deferred_revenue": 0,
        "other_current_liabilities": 0,
        "total_current_liabilities": 48376,
        "longterm_debt": 9879,
        "deferred_revenue_noncurrent": 0,
        "deferred_taxliabilities_noncurrent": 0,
        "other_noncurrent_liabilities": 2939,
        "total_noncurrent_liabilities": 12818,
        "other_liabilities": 2939,
        "capitallease_obligations": 0,
        "total_liabilities": 61194,
        "treasury_stock": 27085,
        "preferred_stock": 0,
        "common_stock": 0,
        "retained_earnings": 27347,
        "additional_paidin_capital": 20705,
        "accumulatedother_comprehensive_incomeloss": -550,
        "other_totalstockholders_equity": 0,
        "total_stockholders_equity": 20417,
        "total_equity": 20417,
        "minority_interest": 0,
        "total_liabilities_and_totalequity": 81611,
        "total_investments": 15083,
        "total_debt": 9879,
        "net_debt": -5202,
        "reported_currency": "USD"
    },
    {
        "updated_at": "2025-02-04",
        "id_financial_report": "PYPL_2023Q4",
        "fiscal_year": 2023,
        "period": "Q4",
        "id_balance_sheet": "PYPL_BS_2023Q4",
        "cash_and_cashequivalents": 9081,
        "short_term_investments": 4979,
        "cash_and_shortterm_investments": 14060,
        "net_receivables": 1069,
        "accounts_receivables": 1069,
        "other_receivables": 0,
        "inventory": 0,
        "prepaids": 2509,
        "other_current_assets": 0,
        "total_current_assets": 62569,
        "property_plant_equipment_net": 1488,
        "goodwill": 11026,
        "intangible_assets": 537,
        "goodwill_and_intangible_assets": 11563,
        "long_term_investments": 3273,
        "tax_assets": 0,
        "other_noncurrent_assets": 3273,
        "total_noncurrent_assets": 18112,
        "other_assets": 3273,
        "total_assets": 82166,
        "total_payables": 6392,
        "account_payables": 139,
        "other_payables": 0,
        "accrued_expenses": 6392,
        "shortterm_debt": 0,
        "capitallease_obligations_current": 0,
        "tax_payables": 0,
        "deferred_revenue": 0,
        "other_current_liabilities": 0,
        "total_current_liabilities": 48466,
        "longterm_debt": 9676,
        "deferred_revenue_noncurrent": 0,
        "deferred_taxliabilities_noncurrent": 0,
        "other_noncurrent_liabilities": 2973,
        "total_noncurrent_liabilities": 12649,
        "other_liabilities": 2973,
        "capitallease_obligations": 0,
        "total_liabilities": 61115,
        "treasury_stock": 21045,
        "preferred_stock": 0,
        "common_stock": 0,
        "retained_earnings": 23200,
        "additional_paidin_capital": 19642,
        "accumulatedother_comprehensive_incomeloss": -746,
        "other_totalstockholders_equity": 0,
        "total_stockholders_equity": 21051,
        "total_equity": 21051,
        "minority_interest": 0,
        "total_liabilities_and_totalequity": 82166,
        "total_investments": 8252,
        "total_debt": 9676,
        "net_debt": 1424,
        "reported_currency": "USD"
    }
]

# Convert JSON to DataFrame
df = pd.DataFrame(json_data)

# Display the DataFrame
df
# Out:
#    updated_at id_financial_report  fiscal_year period id_balance_sheet  \
# 0  2025-02-04         PYPL_2024Q4         2024     Q4   PYPL_BS_2024Q4
# 1  2025-02-04         PYPL_2023Q4         2023     Q4   PYPL_BS_2023Q4
#
#    cash_and_cashequivalents  short_term_investments  \
# 0                      6561                    4262
# 1                      9081                    4979
#
#    cash_and_shortterm_investments  net_receivables  accounts_receivables  ...  \
# 0                           10823              984                   984  ...
# 1                           14060             1069                  1069  ...
#
#    accumulatedother_comprehensive_incomeloss  other_totalstockholders_equity  \
# 0                                       -550                               0
# 1                                       -746                               0
#
#    total_stockholders_equity  total_equity  minority_interest  \
# ...

# %%
    
    df = pd.DataFrame(response)
    print(response)
